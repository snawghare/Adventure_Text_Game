# %%
# Project by Sharvil Nawghare, Team 10 MsBA Hult IBS 2020 fall Python 3

# %%
""" 
Docstring:

Creater: Sharvil Nawghare, 18.10.2020

Hello coders, this game displays an adventure with many twists, focused mainly
on creativity and mix of multiple sports taking place in the space with
different kind of opponents. You will meet some famous characters,
such as Roger Federer and Serena Williams who are your space guides, 
who will coach to you win! The game consists for 6 Sports on 6 different stadiums/
galactic locations. The player needs to win each round to teleport to the 
final round, solve a puzzle and return back to home.
As a player, you control the inputs which will help continue the game,
while in different modes. Have a blast playing!!


"""
#****************************************************************************#

# Known Errors -- Formatting, struggled to have the text lined up in a neat way
    #Worked most of the time but some text has line spaces.



##### Table of Contents for the game code: ######
    
# Import Statements

         #Home Stadium for teams below:
#Room A - Humans 

#Room B - pandas

#Room C - Kangaroos 

#Room D - Sparkling_ants

#Room E - Monkey

#Room F - Flamingos

#Room G - Aliens

#fail_disqualified      (Disqualified = Lost)

#fail_wrong_sport       (Wrong Sport = Lost)

#fail_terimated_evilref (Terminated = Lost)

#fail_defeat_by_deafult (Defeat = Lost)

#winner (Winner)

#****************************************************************************#

print("""

            ******************************** 
            *                              *
            *     'Galactical Olympics'    * 
            *       'Human Vs Aliens'      * 
            *                              *
            ******************************** 
            
                                                                """)

#using skimage to import pictures to make the game more fun visually
#importing time function to slow down steps

from skimage import io
import time

#Image of a space city/ stadium (reference for the picture same as the url:)

url = "https://i.imgur.com/eDdJR.jpg"
io.imshow(io.imread(url))
io.show()

# Tried this code but wasn't able to make it work throughout the game in multiple rooms.

    ## name = input(prompt = "What should the fans on earth call you?\n")
    ##print()
    ##print("Hello, " + name + ". Shall we begin!\n")


#Using global variable to use the player name throughout the game

def athlete_name ():
    global player_name 
    
    player_name = input (prompt = " > ").casefold()
    if player_name in [ "No" , "Yes", ""]:
        print(""" Let's be more creative and rethink the name. """)
        athlete_name()
    
    else:
        return player_name


#****************************************************************************#

# Game introduction dialouge

print("""Wait, what... what is happe.... is this real? what is this? \n
it's so dark and gloomy I just a bright light... where am I?


Hello there, Galatical Warrior from planet Earth! I'm Roger Federer, 
I will guide you to our special event taking place in year 2094, 
the very first Galactical Olympics, between humans and the aliens.
Let me warn you, these are aliens that have evovled over years 
from the human world and they are serious competitors. Alright, let's begin!\n


""")
 
print("Before we begin, what should the fan's on earth call you by? \n\n")

# User Inputs using prompts - Enter your name (using a global variable defined above)
athlete_name ()

print(f""" Hello {player_name} the olympian from planet earth!
today, we will be contesting in Football, Tennis, PingPong, Cricket, 
Curling and Chess. Get excited!!""") 


# Introduction of the olympic games and instructions about the gameplay

print(f""" Suddenly you hear loud cheering... {player_name},{player_name},
you look around you and you see people going crazy, behind you, you see,
Michael freaking Jordan, Who will instruct you further.\n

Hello {player_name}, you are wearing a magic suit with auto controls.
The suit will teleport you from one galactic stadium to the other.
The fan's on earth will be cheering and waiting for your arrival with a medal!\n


In order to win the Olympics you need to win atleast 3 or more Sports!\n""")


#using a pause to let user proccess the above text using a confirm function

#defining confrim

def confirm(): 
    input(prompt = " < Press 'Enter Key' to continue> \n")

confirm()


# Additional Commands to move into later stages of the gameplay

print(f""" Just some more info, with such high intensity of sports and space
as an athlete you would want to consider preserving you enegry for the sport.\
Hence, in later stages should you reach far, you will have an option to redeem,
'Enegry Bars' to refill health. If though you loose a match or run out of steam,
you will be stuck in that galactic space until next olympics. Hence, Your mission, 
should you choose to accept it, As always, should you reject it,
Earth will disavow any knowledge of your participation.\n""")

# Adding another pause before input selection!:
confirm()

#****************************************************************************#

#startgame() -- NOTE to self : WHY DID I ADD THIS here? --- 


#Adding a retry function if the player enters an unknown input. Option to start again. 
def retry (): 
    
    retry_again = input(prompt = """Do you want to retry? Type \"yes\" to return to start or \"no\" to stop: \n""")

    if "yes" in retry_again.casefold():
        print(""" YAY, Let's try again!! \n""")
        startgame()
   
    elif "no" in retry_again.casefold():
        print("""Too bad, we wish to see you next year! \n""")
    
    else:
        print(""" Sorry, I didn't understand that. There might have been an error to enter the olympics! Please try again!\n""")
        retry()
        
        
#********************* INSTRUCTIONS TO START THE GAME! **********************#


def startgame():
    
    startgamee = input (prompt = "Are you ready to compete? (Yes/No or Y/N): ")

    if startgamee.casefold() == 'y' or startgamee.casefold() == 'yes':
        print("Let's rock and rumble!!\n")
        homebase()
        

    elif startgamee.casefold() == 'n' or startgamee.casefold () == 'no':
        print("Too bad, we wish to see you next year! \n")
        retry()

    else: 
        #print("""Sorry, I didn't understand that. There might have been an error to enter the olympics! Please try again!\n""")
        startgame()

        
# Defining names of stadiums when the user moves from one sport to the other. E.G. Going from place x to place y
        

def remodify_stadium(stadium1, stadium2): 
    print(f""" Teleporting to {stadium2}. Zip Zap Zoom!!\n""")
    print(5*"--"+ f" Now teleporting from {stadium1.casefold()}" + 5*"--" + f" This is {stadium2.casefold()}" + 5*"--" + "\n")    
    
        
#****************************************************************************#

#Room/ Game Map input/ defining all the rooms of play from sample script


# ROOM 'A' ON EARTH (Home Base for Human's and Gameplay details)

def homebase () : # homebase = earth
    print(" Let's begin the frist tournament")
    
    input(prompt = f""" Okay, {player_name} from earth, your first sport will 
be against a team of Koala's and you will be playing a match of football.\
When you are ready to go, press the 'enter key' to snap your fingers and teleport. \n\n """)

    
    # Going 3 to 0 (="Begin!") to teleport 
    
    # Importing the time function to slow down the script
    
    #Using While loop for countdown with count
    
    import time
    count = 3
    
    # Counting down teleportaion from homebase to next destination
    while count > 0:
        print(count)
        count -= 1
        time.sleep(1)

    print("Begin!")
    time.sleep(1)
    
    # This will show that destination and Stadiums have now changed from current stadium to the next one
    remodify_stadium("homebase", "Moon")
    
    # Entering next function/Room
    pandas()

#****************************************************************************#

# Room B ON MOON (Home base for Bouncy Panda's and Gameplay details)   

def pandas ():  #pandas = Moon
    
    print(f""" Welcome to the home base of the Bouncy Pandas, the Moon!
The match begins... WHAT! The first blood goes to the pandas who score as
the humans struggle to jump as high as pandas on the bouncy moon! Hold up...
what..{player_name}, performs special tricks and the humans go up 3-1!\ 
Moving them to the second round, The crowd on earth is going nuts after the first win!\n\n""")
    time.sleep(1)
    
    #check if sleep function needs to be added
    
    
    ##Giving user option to choose the next path or next sport they want to play - 'only 1 right option'
    
    next_sport = input (prompt = """  Well Done, you now have a chocie of three sports
    which one would you like to play next?
    
    A. Play Tennis
    B. Play PingPong
    C. Rest on Earth \n""")
    
    ##using if, elif and else statement to guide input or errors in user input 
    
    if next_sport.casefold() == "a" or "tennis" in next_sport.casefold():
    
        remodify_stadium("pandas", "kangaroos")
        kangaroos() 
        #mars (home base for the kangaroos)
    
    elif next_sport.casefold() == "b" or "pingpong" in next_sport.casefold().strip():
        
        remodify_stadium("pandas", "sparkling ants")
        sparkling_ants() 
        #stars (home base for the ants)
        
    elif next_sport.casefold() == "c" or "earth" in next_sport.casefold() or "rest" in next_sport.casefold():
        
        remodify_stadium("pandas", "homebase")
        fail_disqualified() 
        #earth (home base for the humans)
        
    else:
        print("Let's get back in the tournament and try again!")
        pandas()
        #incase of an invalid input, option to restart the level or the same input


#****************************************************************************#
        
# Room C ON MARS (Home base for the red kangaroos)

def kangaroos ():  # kangaroos = mars
        
    print(f""" Welcome to mars, {player_name}. The home base for the four
handed kangaroos. Here we will be playing Tennis and we have a special
coach 'Serena Willams' to help us win! One more rule, as mars is hot,
the balls will be on fire!! coming in hot... lets play!\
        
After long 3 hrs..... kangaroos have been defeted 2 sets out of three\
by the exhausted humans! Way to go, on to the next game! \n\n """)
    time.sleep(1)
    
    ##Giving user option to choose the next path or next sport they want to play
    
    next_game = input (prompt = """  Well Done, you now have a chocie of three sports which one would you like to play next?
    
    A. Play Rock Paper Siccors on Pluto
    B. Play Rugby with Darth Wader
    C. Rest on Earth \n""")
    
    ## using if, elif and else statement to guide input or errors in user input
    
    if next_game.casefold() == "a" or "rock paper siccors" in next_game.casefold().strip() or "pluto" in next_game.casefold(): 
        remodify_stadium("kangaroos", "pluto")
        fail_wrong_sport()
    
    elif next_game.casefold() == "b" or "rugby" in next_game.casefold() or "play" in next_game.casefold():
       
        remodify_stadium("kangaroos", "darth wader")
        fail_terimated_evilref()
    
    elif next_game.casefold() == "c" or "earth" in next_game.casefold() or "rest" in next_game.casefold():
        
        remodify_stadium("kangaroos", "homebase")
        fail_disqualified() 
        #earth (home base for the humans)
        
    else:
        print("Let's get back in the tournament and try again!")
        kangaroos()
         #incase of an invalid input, option to restart the level or the same input


#****************************************************************************#    
        
# Room D ON STARS (Home Base for the Sparkling Ants)

def sparkling_ants (): # sparkling_ants = stars
    
    print(f""" Welcome to the home base of the Sparkling Ants the Twin Stars.
We will be playing PingPong! This should be an easy win for the humans,
as ant's are nervous due to the historic fears of getting crushed
by humans for many year.
            
.....AND... another win for the earthlings, we move to the next match!\n""")
    time.sleep(1)   
    
    
    ##Giving user option to choose the next path or next sport they want to play
    
    next_match = input (prompt = """  Well Done human, you now have a chocie of three sports
    which one would you like to play next?
    
    A. Play Cricket
    B. Play Chess
    C. Rest on Earth \n""")
    
    ## using if, elif and else statement to guide input or errors in user input
    
    if next_match.casefold() == "a" or "cricket" in next_match.casefold():
    
        remodify_stadium("sparkling ants", "flamingos")
        flamingos()  
        #uranus (home base for the flamingos)
    
    elif next_match.casefold() == "b" or "chess" in next_match.casefold():
        
        remodify_stadium("sparkling ants", "monkey")
        monkey () 
        #saturn (home base for the 6 brained monkey)
       
        
    elif next_match.casefold() == "c" or "earth" in next_match.casefold() or "rest" in next_match.casefold():
        
        remodify_stadium("sparkling ants", "homebase")
        fail_disqualified() 
        #earth (home base for the humans)
        
    else:
        print("Let's get back in the tournament and try again!")
        sparkling_ants()
        #incase of an invalid input, option to restart the level or the same input
        

#****************************************************************************#
        
## ROOM E ON Saturn -- (Home Base of the six brained monkey)

def monkey (): # monkey = saturn
    
    print(f""" Welcome {player_name} you are at the home base of the 
six brained monkey, against who you will play a game of chess. Remember
to be calm and use your head. The momkey is ahead but {player_name} is just
as smart! {player_name} edges the monkey after a long mental battle
After a huge cheers from planet earth we move to the ultimate rounds of
this years galactic games!\n\n\n """)
    time.sleep(1)
    
    ##Giving user option to choose the next path or next sport they want to play -- only 2 option here- 1 win 1 lose
    
    ultimate_round = input (prompt = """  Well Done human, you now have to 
    choose out of the remaining sports.\n
    which one would you like to play next?
    
    A. Play Cricket
    B. Rest on Earth \n\n""")
    
    ## using if, elif and else statement to guide input or errors in user input
    
    if ultimate_round.casefold() == "a" or "cricket" in ultimate_round.casefold():
        
        remodify_stadium("monkey", "flamingos")
        flamingos() 
        #uranus (home base for the flamingos)
    
    elif ultimate_round.casefold() == "b" or "earth" in ultimate_round.casefold() or "rest" in ultimate_round.casefold():
        
        remodify_stadium("monkey", "homebase")
        winner()
        #earth (home base for the humans)
        
    else: 
        print("Let's get back in the tournament and try again!")
        monkey()
        #incase of an invalid input, option to restart the level or the same input
        

#****************************************************************************#
        
## ROOM F ON Uranus --- (Home base of the Flamingos)
        
def flamingos (): # flamingos = uranus
    
    print(f""" Hello, welcome to uranus, the home base for the flamingos.
They are the team with an unbreakable bond! But hey, no one has ever been
better at cricket than humans, well show'em how it's done!!
........ well done! we now await for some results, until then lets move on!\n
""")
    time.sleep(2)

    ## USING PROMT AND INPUT FOR A SMALL TWIST IN THE GAME TO SURPRISE PLAYER. 
    ## Giving user option to choose the next path or next sport they want to play

    ultimate_match = input (prompt = f""" But..... Hold on.. you seem exhausted!!! 
To move forward we need to unlock two enegry bars...hold on.. 
the officials will ask you a question to access the bars.\n
QUESTION BY SECURITY OFFICIALS: What do you call a furry being, 
known as a humans best friend, wags the tails and licks endlessly?
Scream (Virtually) your answer in this space!: \n\n""")
    
    
    if "dog" in ultimate_match.casefold() or "doggo" in ultimate_match.casefold() or "cat" in ultimate_match.casefold():
        
        print("""Awesome, you have now recovered and can return back to homebase\n\n""")
        remodify_stadium("flamingos", "homebase")
        winner()
        
    else:
        
        print(""" Oh no!!.... You couldn't get the enegry bars and can't make it to the next round\n""")
        print(""" ********** You are now stuck with flamingos till the next year""")
        fail_defeat_by_deafult
        
    
#****************************************************************************#
    
## ROOM G ON Neptune -- (Home base of the aliens)
    
def aliens (): # aliens = neptune
    
    print(f""" Welcome to neptune, the home base of the aliens.
These aliens invaded Canada and adopted thier culture. They are super
friendly and great at team sports! The sport here is Curling, originated in
canada! Mind you these aliens are a mix of panda's/human and have strong 
bamboo like hands, lets compete!\n\n""")
    time.sleep(1)
    
    ## USING PROMT AND INPUT FOR ANOTHER TWIST IN THE GAME TO SURPRISE PLAYER. 
    
        
    last_round = input (prompt = f""" waitttt... {player_name}. You are about to faint
stand-up... hold on... we have a medical team incoming to restore you health
until then... listen to the people cheering you on all the way from earth!!!\
    

For the medic team to enter alien planet and take you home, you need to 
solve a puzzle... Puzzle = 'In what country is the greatest 
tennis tournament, wimbeldon hosted in?'\ 
    
    Quick enter your answer in this space while you can!: \n\n""")
    time.sleep(1.5)
    
    ## Giving user option to choose the next path or next sport they want to play
    
    if "england" in last_round.casefold() or "london" in last_round.casefold()or "uk" in last_round.casefold() or "united kingdom" in last_round.casefold(): 
        
        print(""" Great Job, you've been saved and crowned a warrior! You will
        now return to homebase earth to your fans! \n\n """)
        remodify_stadium ("aliens", "homebase")
        winner()
        
        
    else: 
        print(""" Oh no!!.... You couldn't get the enegry bars and can't make it to the next round\n""")
        print(""" ********** You are now stuck with the Canadian aliens till the next year""")
        fail_defeat_by_deafult


#****************************************************************************#        

## Fail statement definded option A -- LOSS due to disqualification or choosing to not play      

## Includes a retry function to play the game again        

def fail_disqualified (): 

    print("""oh no! you gave up too early and weren't ready to compete further!!\n""")
    retry()
    

## Fail statement defined option B -- LOSS due to choosing a non-exsisting sport or not reading the script
## Fail by ALIEN TRAPS/DARTH WADER
## Includes a retry function to play the game again

def fail_wrong_sport():

    print(""" You were too tired, choose a non-exsisting sport and fell in the aliens trap.
Please choose another team or stadium next time around!\n\n """)
    retry()

    
## Fail statement defined option C -- LOSS due to not reading the script
## Fail by choosing DARTH WADER --- Obviously he evil

def fail_terimated_evilref():

    print(f""" Oh no! you fell in the trap, darth wader had hacked the games
and tricked you into falling for his trap. Go back and choose another sport to win!\n\n """)
    pandas()
       
## Fail statement defined option D -- LOSS due to not knowing input puzzle answer and also due to physical defeat in game - Out of GAS-
## Option to retry included

def fail_defeat_by_deafult():
    
    print(f""" You entered the galactic olympics without being in good shape, you ran out of gas and were\
defeated by default! You will be stuck on at this tournament until the next edition!\
stay safe until then!!\n\n\n""")
    retry()
    
## Defining the Winning Statement- after solvling one of the two puzzles!

def winner():
    
    print(f""" {player_name}, you have now conquered the galactic universe and are the champion! Enjoy your celebrations on earth!""", end = "") 

## USER GETTING AN AWARD ON EARTH BY ROGER FEDERER IN LONDON
   
    url = "https://image-cdn.essentiallysports.com/wp-content/uploads/20200729180544/Federer-Olympics-1.jpg"

    io.imshow(io.imread(url))
    io.show()
    
### Recall the begining function again to restart game 
    time.sleep(2)
    print("start again!")
    startgame()

#****************************************************************************#

startgame()
# Out:
#             ********************************
#             *                              *
#             *     'Galactical Olympics'    *
#             *       'Human Vs Aliens'      *
#             *                              *
#             ********************************
# Wait, what... what is happe.... is this real? what is this?
#
# it's so dark and gloomy I just a bright light... where am I?
#
#
# Hello there, Galatical Warrior from planet Earth! I'm Roger Federer,
# I will guide you to our special event taking place in year 2094,
# the very first Galactical Olympics, between humans and the aliens.
# Let me warn you, these are aliens that have evovled over years
# from the human world and they are serious competitors. Alright, let's begin!
#
#
#
#
# Before we begin, what should the fan's on earth call you by?
#
#
#  > Shark
#  Hello shark the olympian from planet earth!
# today, we will be contesting in Football, Tennis, PingPong, Cricket,
# ...
